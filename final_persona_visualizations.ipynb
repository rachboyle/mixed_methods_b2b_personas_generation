# %% [markdown]
# <a href="https://colab.research.google.com/github/rachboyle/mixed_methods_b2b_personas_generation/blob/main/final_persona_visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Our Final Personas

# %%
#Authenticate to GCP to access survey and web analytics data in BigQuery
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ##Imports

# %%
#Install UMAP (dimensionality reduction) and HDBscan (clustering algorithm)
# !pip install umap-learn
# !pip install hdbscan

# %%
import pandas as pd
from sklearn.cluster import KMeans
from IPython.display import display_html
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
plt.rcParams.update({'figure.max_open_warning': 0}) #set so you do not get warnings

from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Dimension reduction and clustering libraries
import umap.umap_ as umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
from sklearn.preprocessing import normalize, StandardScaler

# %% [markdown]
# ##Visualizations

# %%
# %%bigquery --project uxr-design-us-dev personas_df
# SELECT * FROM mixed_methods_clustering.final_six_personas_hdb_scan_umap

# %%
summary = personas_df[personas_df.columns.tolist()[2::]].groupby(["persona_label"]).mean()
summary['count'] = personas_df["persona_label"].value_counts()
summary = summary.sort_values(by='count', ascending=False)
summary
# Out:
#                _tkt5orHUpCVLIts2gorwT3UgG5I  ...  count
# persona_label                                ...
# generalist                         0.000000  ...   1948
# data_buyer                         0.000000  ...   1107
# uploader                           0.000000  ...   1075
# data_seller                        0.000000  ...    836
# agency_user                        0.000000  ...    707
# tv_user                            0.585677  ...    133
#
# [6 rows x 84 columns]

# %%
cluster_means_and_plots_both(summary, 10, "generalist") 
cluster_means_and_plots_both(summary, 10, "data_buyer") 
cluster_means_and_plots_both(summary, 10, "uploader") 
cluster_means_and_plots_both(summary, 10, "data_seller") 
cluster_means_and_plots_both(summary, 10, "agency_user") 
cluster_means_and_plots_both(summary, 10, "tv_user")
# Out:
# PERSONA CLUSTER: generalist
#
# NUMBER OF USERS IN CLUSTER: 1948.0
#
# PERCENTAGE OF USERS IN CLUSTER: 33.551
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>17.287479</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>16.077017</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>15.052168</td>
#     </tr>
#     <tr>
#       <th>My Files</th>
#       <td>14.766750</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>10.040876</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>9.501386</td>
#     </tr>
#     <tr>
#       <th>FIle Upload Simple Onboarding</th>
#       <td>9.169007</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - Edit Account</th>
#       <td>7.031499</td>
#     </tr>
#     <tr>
#       <th>Destinations List</th>
#       <td>5.782186</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Profile Tab</th>
#       <td>5.554165</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>17.553375</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>5.917170</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>2.948211</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>2.934638</td>
#     </tr>
#     <tr>
#       <th>Upload File &gt; Upload File Button</th>
#       <td>1.307240</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>0.290207</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>0.219461</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>0.217806</td>
#     </tr>
#     <tr>
#       <th>Company Settings &gt; Audiences Tab &gt; New Audience Button</th>
#       <td>0.125642</td>
#     </tr>
#     <tr>
#       <th>DA Config &gt; Create Destination Account Button</th>
#       <td>0.112996</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# PERSONA CLUSTER: data_buyer
#
# NUMBER OF USERS IN CLUSTER: 1107.0
#
# PERCENTAGE OF USERS IN CLUSTER: 19.066
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Buy Data</th>
#       <td>41.474597</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>15.024497</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>12.579695</td>
#     </tr>
#     <tr>
#       <th>Storefront</th>
#       <td>10.752743</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>9.219443</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>8.635319</td>
#     </tr>
#     <tr>
#       <th>DM - Storefront - Partner Detail</th>
#       <td>7.344499</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>7.173670</td>
#     </tr>
#     <tr>
#       <th>My Files</th>
#       <td>6.690887</td>
#     </tr>
#     <tr>
#       <th>FIle Upload Simple Onboarding</th>
#       <td>4.832376</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>25.021932</td>
#     </tr>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>11.679858</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>6.132920</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>4.459272</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>3.975427</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>0.736782</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>0.377558</td>
#     </tr>
#     <tr>
#       <th>Upload File &gt; Upload File Button</th>
#       <td>0.266181</td>
#     </tr>
#     <tr>
#       <th>DA Config &gt; Create Destination Account Button</th>
#       <td>0.125675</td>
#     </tr>
#     <tr>
#       <th>Company Settings &gt; Audiences Tab &gt; New Audience Button</th>
#       <td>0.066983</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# PERSONA CLUSTER: uploader
#
# NUMBER OF USERS IN CLUSTER: 1075.0
#
# PERCENTAGE OF USERS IN CLUSTER: 18.515
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>My Files</th>
#       <td>17.491468</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>16.829118</td>
#     </tr>
#     <tr>
#       <th>FIle Upload Simple Onboarding</th>
#       <td>16.493959</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>14.956707</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>12.094123</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>10.924762</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>9.467416</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Audiences Tab</th>
#       <td>4.435966</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Profile Tab</th>
#       <td>2.820731</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - Edit Account</th>
#       <td>2.429960</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>12.267971</td>
#     </tr>
#     <tr>
#       <th>Upload File &gt; Upload File Button</th>
#       <td>4.394829</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>3.601576</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>0.531156</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>0.403305</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>0.007737</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>0.005395</td>
#     </tr>
#     <tr>
#       <th>Company Settings &gt; Audiences Tab &gt; New Audience Button</th>
#       <td>0.005349</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>0.004372</td>
#     </tr>
#     <tr>
#       <th>DA Config &gt; Create Destination Account Button</th>
#       <td>0.002062</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# PERSONA CLUSTER: data_seller
#
# NUMBER OF USERS IN CLUSTER: 836.0
#
# PERCENTAGE OF USERS IN CLUSTER: 14.399
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Sell Data (All Tabs)</th>
#       <td>19.581599</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>16.130578</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>14.269533</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>13.545687</td>
#     </tr>
#     <tr>
#       <th>Sell Data - My Segments</th>
#       <td>11.797409</td>
#     </tr>
#     <tr>
#       <th>My Files</th>
#       <td>9.006896</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>8.709249</td>
#     </tr>
#     <tr>
#       <th>Buy Data</th>
#       <td>7.203044</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>6.629839</td>
#     </tr>
#     <tr>
#       <th>Sell Data - Distribution Status</th>
#       <td>5.269802</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>11.617518</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>6.899874</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>4.637228</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>1.577149</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>1.434696</td>
#     </tr>
#     <tr>
#       <th>Sell Data &gt; Batch Upload &gt; File Drop Zone</th>
#       <td>1.038260</td>
#     </tr>
#     <tr>
#       <th>Manage Data &gt; Audience &gt; Create Segment &gt; Create</th>
#       <td>0.737440</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>0.713677</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>0.644599</td>
#     </tr>
#     <tr>
#       <th>Sell Data &gt; Distribution Status &gt; Search</th>
#       <td>0.634886</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# PERSONA CLUSTER: agency_user
#
# NUMBER OF USERS IN CLUSTER: 707.0
#
# PERCENTAGE OF USERS IN CLUSTER: 12.177
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>14.314030</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>12.744009</td>
#     </tr>
#     <tr>
#       <th>My Files</th>
#       <td>12.582974</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>12.351063</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Users Tab</th>
#       <td>9.663632</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>9.150992</td>
#     </tr>
#     <tr>
#       <th>Buy Data</th>
#       <td>8.189307</td>
#     </tr>
#     <tr>
#       <th>FIle Upload Simple Onboarding</th>
#       <td>8.169976</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>7.879950</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Audiences Tab</th>
#       <td>7.575315</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>13.298585</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>6.785666</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>5.639527</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>4.696365</td>
#     </tr>
#     <tr>
#       <th>Company Settings &gt; Audiences Tab &gt; New Audience Button</th>
#       <td>2.107125</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>2.024039</td>
#     </tr>
#     <tr>
#       <th>DA Config &gt; Create Destination Account Button</th>
#       <td>1.879567</td>
#     </tr>
#     <tr>
#       <th>Upload File &gt; Upload File Button</th>
#       <td>1.630999</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>0.830562</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>0.686630</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# PERSONA CLUSTER: tv_user
#
# NUMBER OF USERS IN CLUSTER: 133.0
#
# PERCENTAGE OF USERS IN CLUSTER: 2.291
# Top Pages on Left, Top Features on Right
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>page</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Buy Data</th>
#       <td>7.455487</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts - My Segments</th>
#       <td>3.493960</td>
#     </tr>
#     <tr>
#       <th>My Dashboard</th>
#       <td>3.012546</td>
#     </tr>
#     <tr>
#       <th>My Segments</th>
#       <td>3.006855</td>
#     </tr>
#     <tr>
#       <th>Your Destination Accounts</th>
#       <td>2.842607</td>
#     </tr>
#     <tr>
#       <th>Audience - Segments</th>
#       <td>2.178144</td>
#     </tr>
#     <tr>
#       <th>Storefront</th>
#       <td>1.836381</td>
#     </tr>
#     <tr>
#       <th>My Files</th>
#       <td>1.637336</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Audiences Tab</th>
#       <td>1.378383</td>
#     </tr>
#     <tr>
#       <th>Company Settings - Profile Tab</th>
#       <td>1.340534</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Buy Data &gt; Search Segment</th>
#       <td>3.087521</td>
#     </tr>
#     <tr>
#       <th>My Destinations &gt; Manage Existing DA Button</th>
#       <td>1.912853</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Add to Distribution Button</th>
#       <td>0.834671</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Download Segment(s)</th>
#       <td>0.666499</td>
#     </tr>
#     <tr>
#       <th>Buy Data &gt; Request Segment</th>
#       <td>0.588337</td>
#     </tr>
#     <tr>
#       <th>DA &gt; My Segments &gt; Footer &gt; Remove From Distribution</th>
#       <td>0.313330</td>
#     </tr>
#     <tr>
#       <th>Upload File &gt; Upload File Button</th>
#       <td>0.059641</td>
#     </tr>
#     <tr>
#       <th>DA Config &gt; Create Destination Account Button</th>
#       <td>0.027068</td>
#     </tr>
#     <tr>
#       <th>Global Action Button / +New User</th>
#       <td>0.009774</td>
#     </tr>
#     <tr>
#       <th>My Segments &gt; Overlap Segments</th>
#       <td>0.006015</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
summary['count']
# Out:
# persona_label
# generalist     1948
# data_buyer     1107
# uploader       1075
# data_seller     836
# agency_user     707
# tv_user         133
# Name: count, dtype: int64
